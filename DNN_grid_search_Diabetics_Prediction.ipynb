# %%
import pandas as pd
import numpy as np
import sklearn
import keras

# %%
# Import uci prima indians diabetis dataset

df = pd.read_csv("diabetes.csv")

# %%
# Describe the dataset

df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
df[df['Glucose']==0]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 75             1        0             48             20        0  24.7
# 182            1        0             74             20       23  27.7
# 342            1        0             68             35        0  32.0
# 349            5        0             80             32        0  41.0
# 502            6        0             68             41        0  39.0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 75                      0.140   22        0
# 182                     0.299   21        0
# 342                     0.389   22        0
# 349                     0.346   37        1
# 502                     0.727   41        1

# %%
# Preprocess the data
# Make all the zero data NA and remove

columns = ['Glucose','BloodPressure','SkinThickness','Insulin','BMI']

for col in columns:
  df[col].replace(0, np.NaN, inplace=True)

df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  763.000000     733.000000     541.000000  394.000000
# mean      3.845052  121.686763      72.405184      29.153420  155.548223
# std       3.369578   30.535641      12.382158      10.476982  118.775855
# min       0.000000   44.000000      24.000000       7.000000   14.000000
# 25%       1.000000   99.000000      64.000000      22.000000   76.250000
# 50%       3.000000  117.000000      72.000000      29.000000  125.000000
# 75%       6.000000  141.000000      80.000000      36.000000  190.000000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  757.000000                768.000000  768.000000  768.000000
# mean    32.457464                  0.471876   33.240885    0.348958
# std      6.924988                  0.331329   11.760232    0.476951
# min     18.200000                  0.078000   21.000000    0.000000
# 25%     27.500000                  0.243750   24.000000    0.000000
# 50%     32.300000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
# Drop rows with missing columns
df.dropna(inplace=True)

df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   392.000000  392.000000     392.000000     392.000000  392.000000
# mean      3.301020  122.627551      70.663265      29.145408  156.056122
# std       3.211424   30.860781      12.496092      10.516424  118.841690
# min       0.000000   56.000000      24.000000       7.000000   14.000000
# 25%       1.000000   99.000000      62.000000      21.000000   76.750000
# 50%       2.000000  119.000000      70.000000      29.000000  125.500000
# 75%       5.000000  143.000000      78.000000      37.000000  190.000000
# max      17.000000  198.000000     110.000000      63.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  392.000000                392.000000  392.000000  392.000000
# mean    33.086224                  0.523046   30.864796    0.331633
# std      7.027659                  0.345488   10.200777    0.471401
# min     18.200000                  0.085000   21.000000    0.000000
# 25%     28.400000                  0.269750   23.000000    0.000000
# 50%     33.200000                  0.449500   27.000000    0.000000
# 75%     37.100000                  0.687000   36.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
# Convert dataframe into numpy array

dataset = df.values
print(dataset.shape)
# Out:
# (392, 9)

# %%
# Split into input x and y

X = dataset[:,0:8]
Y = dataset[:,8].astype(int)

print(X.shape)
print(Y.shape)
print(X[:2])
print(Y[:2])
# Out:
# (392, 8)
# (392,)
# [[1.000e+00 8.900e+01 6.600e+01 2.300e+01 9.400e+01 2.810e+01 1.670e-01
#   2.100e+01]
#  [0.000e+00 1.370e+02 4.000e+01 3.500e+01 1.680e+02 4.310e+01 2.288e+00
#   3.300e+01]]
# [0 1]

# %%
# Normalise the data using sklearn StandardScaler

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(X)

# %%
# Transform and Display the data

X_stand = scaler.transform(X)

data = pd.DataFrame(X_stand)
data.describe()
# Out:
#                   0             1             2             3             4  \
# count  3.920000e+02  3.920000e+02  3.920000e+02  3.920000e+02  3.920000e+02
# mean  -9.063045e-18  1.132881e-17 -4.531523e-16  1.087565e-16  1.064908e-16
# std    1.001278e+00  1.001278e+00  1.001278e+00  1.001278e+00  1.001278e+00
# min   -1.029213e+00 -2.161731e+00 -3.739001e+00 -2.108484e+00 -1.196867e+00
# 25%   -7.174265e-01 -7.665958e-01 -6.941640e-01 -7.755315e-01 -6.681786e-01
# 50%   -4.056403e-01 -1.176959e-01 -5.314565e-02 -1.384444e-02 -2.574448e-01
# 75%    5.297185e-01  6.609841e-01  5.878727e-01  7.478426e-01  2.859877e-01
# max    4.271153e+00  2.445459e+00  3.151946e+00  3.223325e+00  5.812990e+00
#
#                   5             6             7
# count  3.920000e+02  3.920000e+02  3.920000e+02
# mean   1.631348e-16  1.812609e-17  1.110223e-16
# std    1.001278e+00  1.001278e+00  1.001278e+00
# min   -2.120941e+00 -1.269525e+00 -9.682991e-01
# 25%   -6.676780e-01 -7.340909e-01 -7.719850e-01
# 50%    1.621036e-02 -2.131475e-01 -3.793569e-01
# 75%    5.718696e-01  4.751644e-01  5.040564e-01
# max    4.846172e+00  5.497667e+00  4.921123e+00

# %%
from sklearn.model_selection import GridSearchCV, KFold
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam

# %%
# Start Defining the model

def create_model():
  #create model
  model = Sequential()
  model.add(Dense(8, input_dim = 8, kernel_initializer = 'normal', activation = 'relu'))
  model.add(Dense(4, input_dim = 8, kernel_initializer = 'normal', activation = 'relu'))
  model.add(Dense(1, activation = 'sigmoid'))

  #compile the model
  adam = Adam(lr = 0.01)
  model.compile(loss = 'binary_crossentropy', optimizer = adam, metrics = ['accuracy'])
  return model

model = create_model()
print(model.summary())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 8)                 72
#
#  dense_1 (Dense)             (None, 4)                 36
#
#  dense_2 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 113
# Trainable params: 113
# Non-trainable params: 0
# _________________________________________________________________
# None
# /usr/local/lib/python3.10/dist-packages/keras/optimizers/legacy/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
# Random Seed

seed = 6
np.random.seed(seed)

# Start Defining the model

def create_model():
  #create model
  model = Sequential()
  model.add(Dense(8, input_dim = 8, kernel_initializer = 'normal', activation = 'relu'))
  model.add(Dense(4, input_dim = 8, kernel_initializer = 'normal', activation = 'relu'))
  model.add(Dense(1, activation = 'sigmoid'))

  #compile the model
  adam = Adam(lr = 0.01)
  model.compile(loss = 'binary_crossentropy', optimizer = adam, metrics = ['accuracy'])
  return model

# Create Model
model = KerasClassifier(build_fn = create_model, verbose = 0)

# Define GridSearch Parameters
batch_size = [10, 20, 40]
epochs = [10, 50, 100]

# Make a dictionary of grid search parameters
param_grid = dict(batch_size=batch_size, epochs=epochs)

# Build and Fit GridSearchCV
grid = GridSearchCV(estimator = model, param_grid = param_grid, cv = KFold(), verbose = 10)
grid_result = grid.fit(X_stand, Y)

# Summarise Results
print("Best: {0}, using {1}".format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']

for mean,stddev, param in zip(means,stds,params):
  print('{0} {1}, with: {2}'.format(mean,stddev,param))
# Out:
# <ipython-input-26-d93d33c104a1>:21: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasClassifier(build_fn = create_model, verbose = 0)
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5; 1/9] START batch_size=10, epochs=10....................................
# [CV 1/5; 1/9] END .....batch_size=10, epochs=10;, score=0.747 total time=   1.4s
# [CV 2/5; 1/9] START batch_size=10, epochs=10....................................
# [CV 2/5; 1/9] END .....batch_size=10, epochs=10;, score=0.608 total time=   1.3s
# [CV 3/5; 1/9] START batch_size=10, epochs=10....................................
# [CV 3/5; 1/9] END .....batch_size=10, epochs=10;, score=0.808 total time=   1.6s
# [CV 4/5; 1/9] START batch_size=10, epochs=10....................................
# [CV 4/5; 1/9] END .....batch_size=10, epochs=10;, score=0.872 total time=   2.3s
# [CV 5/5; 1/9] START batch_size=10, epochs=10....................................
# [CV 5/5; 1/9] END .....batch_size=10, epochs=10;, score=0.846 total time=   1.4s
# [CV 1/5; 2/9] START batch_size=10, epochs=50....................................
# [CV 1/5; 2/9] END .....batch_size=10, epochs=50;, score=0.797 total time=   3.1s
# [CV 2/5; 2/9] START batch_size=10, epochs=50....................................
# [CV 2/5; 2/9] END .....batch_size=10, epochs=50;, score=0.696 total time=   3.8s
# [CV 3/5; 2/9] START batch_size=10, epochs=50....................................
# [CV 3/5; 2/9] END .....batch_size=10, epochs=50;, score=0.782 total time=   3.9s
# [CV 4/5; 2/9] START batch_size=10, epochs=50....................................
# [CV 4/5; 2/9] END .....batch_size=10, epochs=50;, score=0.846 total time=   3.4s
# [CV 5/5; 2/9] START batch_size=10, epochs=50....................................
# [CV 5/5; 2/9] END .....batch_size=10, epochs=50;, score=0.833 total time=   3.2s
# [CV 1/5; 3/9] START batch_size=10, epochs=100...................................
# [CV 1/5; 3/9] END ....batch_size=10, epochs=100;, score=0.747 total time=  11.0s
# [CV 2/5; 3/9] START batch_size=10, epochs=100...................................
# [CV 2/5; 3/9] END ....batch_size=10, epochs=100;, score=0.658 total time=   6.0s
# [CV 3/5; 3/9] START batch_size=10, epochs=100...................................
# [CV 3/5; 3/9] END ....batch_size=10, epochs=100;, score=0.782 total time=   5.7s
# [CV 4/5; 3/9] START batch_size=10, epochs=100...................................
# [CV 4/5; 3/9] END ....batch_size=10, epochs=100;, score=0.833 total time=   6.0s
# [CV 5/5; 3/9] START batch_size=10, epochs=100...................................
# [CV 5/5; 3/9] END ....batch_size=10, epochs=100;, score=0.821 total time=   6.2s
# [CV 1/5; 4/9] START batch_size=20, epochs=10....................................
# [CV 1/5; 4/9] END .....batch_size=20, epochs=10;, score=0.759 total time=   1.0s
# [CV 2/5; 4/9] START batch_size=20, epochs=10....................................
# [CV 2/5; 4/9] END .....batch_size=20, epochs=10;, score=0.608 total time=   1.1s
# [CV 3/5; 4/9] START batch_size=20, epochs=10....................................
# [CV 3/5; 4/9] END .....batch_size=20, epochs=10;, score=0.859 total time=   1.1s
# [CV 4/5; 4/9] START batch_size=20, epochs=10....................................
# [CV 4/5; 4/9] END .....batch_size=20, epochs=10;, score=0.846 total time=   1.0s
# [CV 5/5; 4/9] START batch_size=20, epochs=10....................................
# [CV 5/5; 4/9] END .....batch_size=20, epochs=10;, score=0.821 total time=   1.2s
# [CV 1/5; 5/9] START batch_size=20, epochs=50....................................
# [CV 1/5; 5/9] END .....batch_size=20, epochs=50;, score=0.772 total time=   2.7s
# [CV 2/5; 5/9] START batch_size=20, epochs=50....................................
# [CV 2/5; 5/9] END .....batch_size=20, epochs=50;, score=0.658 total time=   3.4s
# [CV 3/5; 5/9] START batch_size=20, epochs=50....................................
# [CV 3/5; 5/9] END .....batch_size=20, epochs=50;, score=0.782 total time=   2.0s
# [CV 4/5; 5/9] START batch_size=20, epochs=50....................................
# [CV 4/5; 5/9] END .....batch_size=20, epochs=50;, score=0.821 total time=   2.6s
# [CV 5/5; 5/9] START batch_size=20, epochs=50....................................
# [CV 5/5; 5/9] END .....batch_size=20, epochs=50;, score=0.846 total time=   3.5s
# [CV 1/5; 6/9] START batch_size=20, epochs=100...................................
# [CV 1/5; 6/9] END ....batch_size=20, epochs=100;, score=0.747 total time=   5.9s
# [CV 2/5; 6/9] START batch_size=20, epochs=100...................................
# [CV 2/5; 6/9] END ....batch_size=20, epochs=100;, score=0.684 total time=   3.4s
# [CV 3/5; 6/9] START batch_size=20, epochs=100...................................
# [CV 3/5; 6/9] END ....batch_size=20, epochs=100;, score=0.833 total time=   5.9s
# [CV 4/5; 6/9] START batch_size=20, epochs=100...................................
# [CV 4/5; 6/9] END ....batch_size=20, epochs=100;, score=0.756 total time=   3.4s
# [CV 5/5; 6/9] START batch_size=20, epochs=100...................................
# [CV 5/5; 6/9] END ....batch_size=20, epochs=100;, score=0.821 total time=   3.4s
# [CV 1/5; 7/9] START batch_size=40, epochs=10....................................
# [CV 1/5; 7/9] END .....batch_size=40, epochs=10;, score=0.797 total time=   1.3s
# [CV 2/5; 7/9] START batch_size=40, epochs=10....................................
# [CV 2/5; 7/9] END .....batch_size=40, epochs=10;, score=0.620 total time=   1.4s
# [CV 3/5; 7/9] START batch_size=40, epochs=10....................................
# [CV 3/5; 7/9] END .....batch_size=40, epochs=10;, score=0.782 total time=   1.0s
# [CV 4/5; 7/9] START batch_size=40, epochs=10....................................
# [CV 4/5; 7/9] END .....batch_size=40, epochs=10;, score=0.795 total time=   1.1s
# [CV 5/5; 7/9] START batch_size=40, epochs=10....................................
# [CV 5/5; 7/9] END .....batch_size=40, epochs=10;, score=0.846 total time=   0.9s
# [CV 1/5; 8/9] START batch_size=40, epochs=50....................................
# [CV 1/5; 8/9] END .....batch_size=40, epochs=50;, score=0.734 total time=   2.1s
# [CV 2/5; 8/9] START batch_size=40, epochs=50....................................
# [CV 2/5; 8/9] END .....batch_size=40, epochs=50;, score=0.658 total time=   2.0s
# [CV 3/5; 8/9] START batch_size=40, epochs=50....................................
# [CV 3/5; 8/9] END .....batch_size=40, epochs=50;, score=0.833 total time=   2.0s
# [CV 4/5; 8/9] START batch_size=40, epochs=50....................................
# [CV 4/5; 8/9] END .....batch_size=40, epochs=50;, score=0.808 total time=   2.2s
# [CV 5/5; 8/9] START batch_size=40, epochs=50....................................
# [CV 5/5; 8/9] END .....batch_size=40, epochs=50;, score=0.833 total time=   2.3s
# [CV 1/5; 9/9] START batch_size=40, epochs=100...................................
# [CV 1/5; 9/9] END ....batch_size=40, epochs=100;, score=0.772 total time=   2.2s
# [CV 2/5; 9/9] START batch_size=40, epochs=100...................................
# [CV 2/5; 9/9] END ....batch_size=40, epochs=100;, score=0.684 total time=   3.0s
# [CV 3/5; 9/9] START batch_size=40, epochs=100...................................
# [CV 3/5; 9/9] END ....batch_size=40, epochs=100;, score=0.808 total time=   2.3s
# [CV 4/5; 9/9] START batch_size=40, epochs=100...................................
# [CV 4/5; 9/9] END ....batch_size=40, epochs=100;, score=0.821 total time=   2.8s
# [CV 5/5; 9/9] START batch_size=40, epochs=100...................................
# [CV 5/5; 9/9] END ....batch_size=40, epochs=100;, score=0.821 total time=   2.6s
# Best: 0.7910418629646301, using {'batch_size': 10, 'epochs': 50}
# 0.7760142803192138 0.09414187971252792, with: {'batch_size': 10, 'epochs': 10}
# 0.7910418629646301 0.052806308109099205, with: {'batch_size': 10, 'epochs': 50}
# 0.7681921482086181 0.06280310912448411, with: {'batch_size': 10, 'epochs': 100}
# 0.7785459160804749 0.09207390801758203, with: {'batch_size': 20, 'epochs': 10}
# 0.7758195400238037 0.0645360290897271, with: {'batch_size': 20, 'epochs': 50}
# 0.7681272268295288 0.054297305906073214, with: {'batch_size': 20, 'epochs': 100}
# 0.7681596875190735 0.07710375752326488, with: {'batch_size': 40, 'epochs': 10}
# 0.7733528017997742 0.06806320777215036, with: {'batch_size': 40, 'epochs': 50}
# 0.7808828234672547 0.051789659466734285, with: {'batch_size': 40, 'epochs': 100}

# %%
# Random Seed

seed = 6
np.random.seed(seed)

from keras.layers import Dropout

# Start Defining the model

def create_model(learn_rate, dropout_rate):
  #create model
  model = Sequential()
  model.add(Dense(8, input_dim = 8, kernel_initializer = 'normal', activation = 'relu'))
  model.add(Dropout(dropout_rate))
  model.add(Dense(4, input_dim = 8, kernel_initializer = 'normal', activation = 'relu'))
  model.add(Dropout(dropout_rate))
  model.add(Dense(1, activation = 'sigmoid'))

  #compile the model
  adam = Adam(lr = learn_rate)
  model.compile(loss = 'binary_crossentropy', optimizer = adam, metrics = ['accuracy'])
  return model

# Create Model
model = KerasClassifier(build_fn = create_model, epochs = 50, batch_size = 10, verbose = 0)

# Define GridSearch Parameters
learn_rate = [0.001,0.01,0.1]
dropout_rate = [0.0,0.1,0.2]

# Make a dictionary of grid search parameters
param_grid = dict(learn_rate=learn_rate, dropout_rate=dropout_rate)

# Build and Fit GridSearchCV
grid = GridSearchCV(estimator = model, param_grid = param_grid, cv = KFold(), verbose = 10)
grid_result = grid.fit(X_stand, Y)

# Summarise Results
print("Best: {0}, using {1}".format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']

for mean,stddev, param in zip(means,stds,params):
  print('{0} {1}, with: {2}'.format(mean,stddev,param))
# Out:
# <ipython-input-27-8aee3c1da684>:25: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasClassifier(build_fn = create_model, epochs = 50, batch_size = 10, verbose = 0)
# /usr/local/lib/python3.10/dist-packages/keras/optimizers/legacy/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5; 1/9] START dropout_rate=0.0, learn_rate=0.001..........................
# [CV 1/5; 1/9] END dropout_rate=0.0, learn_rate=0.001;, score=0.772 total time=   3.9s
# [CV 2/5; 1/9] START dropout_rate=0.0, learn_rate=0.001..........................
# [CV 2/5; 1/9] END dropout_rate=0.0, learn_rate=0.001;, score=0.595 total time=   3.9s
# [CV 3/5; 1/9] START dropout_rate=0.0, learn_rate=0.001..........................
# [CV 3/5; 1/9] END dropout_rate=0.0, learn_rate=0.001;, score=0.821 total time=   3.4s
# [CV 4/5; 1/9] START dropout_rate=0.0, learn_rate=0.001..........................
# [CV 4/5; 1/9] END dropout_rate=0.0, learn_rate=0.001;, score=0.833 total time=   3.2s
# [CV 5/5; 1/9] START dropout_rate=0.0, learn_rate=0.001..........................
# [CV 5/5; 1/9] END dropout_rate=0.0, learn_rate=0.001;, score=0.872 total time=   5.9s
# [CV 1/5; 2/9] START dropout_rate=0.0, learn_rate=0.01...........................
# [CV 1/5; 2/9] END dropout_rate=0.0, learn_rate=0.01;, score=0.696 total time=   3.4s
# [CV 2/5; 2/9] START dropout_rate=0.0, learn_rate=0.01...........................
# [CV 2/5; 2/9] END dropout_rate=0.0, learn_rate=0.01;, score=0.658 total time=   3.3s
# [CV 3/5; 2/9] START dropout_rate=0.0, learn_rate=0.01...........................
# [CV 3/5; 2/9] END dropout_rate=0.0, learn_rate=0.01;, score=0.795 total time=   5.9s
# [CV 4/5; 2/9] START dropout_rate=0.0, learn_rate=0.01...........................
# [CV 4/5; 2/9] END dropout_rate=0.0, learn_rate=0.01;, score=0.821 total time=   3.1s
# [CV 5/5; 2/9] START dropout_rate=0.0, learn_rate=0.01...........................
# [CV 5/5; 2/9] END dropout_rate=0.0, learn_rate=0.01;, score=0.846 total time=   3.3s
# [CV 1/5; 3/9] START dropout_rate=0.0, learn_rate=0.1............................
# [CV 1/5; 3/9] END dropout_rate=0.0, learn_rate=0.1;, score=0.709 total time=   5.9s
# [CV 2/5; 3/9] START dropout_rate=0.0, learn_rate=0.1............................
# [CV 2/5; 3/9] END dropout_rate=0.0, learn_rate=0.1;, score=0.608 total time=   3.1s
# [CV 3/5; 3/9] START dropout_rate=0.0, learn_rate=0.1............................
# [CV 3/5; 3/9] END dropout_rate=0.0, learn_rate=0.1;, score=0.833 total time=   4.1s
# [CV 4/5; 3/9] START dropout_rate=0.0, learn_rate=0.1............................
# [CV 4/5; 3/9] END dropout_rate=0.0, learn_rate=0.1;, score=0.833 total time=   4.0s
# [CV 5/5; 3/9] START dropout_rate=0.0, learn_rate=0.1............................
# [CV 5/5; 3/9] END dropout_rate=0.0, learn_rate=0.1;, score=0.795 total time=   3.4s
# [CV 1/5; 4/9] START dropout_rate=0.1, learn_rate=0.001..........................
# [CV 1/5; 4/9] END dropout_rate=0.1, learn_rate=0.001;, score=0.747 total time=   3.4s
# [CV 2/5; 4/9] START dropout_rate=0.1, learn_rate=0.001..........................
# [CV 2/5; 4/9] END dropout_rate=0.1, learn_rate=0.001;, score=0.595 total time=   6.0s
# [CV 3/5; 4/9] START dropout_rate=0.1, learn_rate=0.001..........................
# [CV 3/5; 4/9] END dropout_rate=0.1, learn_rate=0.001;, score=0.808 total time=   3.4s
# [CV 4/5; 4/9] START dropout_rate=0.1, learn_rate=0.001..........................
# [CV 4/5; 4/9] END dropout_rate=0.1, learn_rate=0.001;, score=0.821 total time=   3.3s
# [CV 5/5; 4/9] START dropout_rate=0.1, learn_rate=0.001..........................
# [CV 5/5; 4/9] END dropout_rate=0.1, learn_rate=0.001;, score=0.846 total time=   6.0s
# [CV 1/5; 5/9] START dropout_rate=0.1, learn_rate=0.01...........................
# [CV 1/5; 5/9] END dropout_rate=0.1, learn_rate=0.01;, score=0.772 total time=   3.4s
# [CV 2/5; 5/9] START dropout_rate=0.1, learn_rate=0.01...........................
# [CV 2/5; 5/9] END dropout_rate=0.1, learn_rate=0.01;, score=0.633 total time=   3.4s
# [CV 3/5; 5/9] START dropout_rate=0.1, learn_rate=0.01...........................
# [CV 3/5; 5/9] END dropout_rate=0.1, learn_rate=0.01;, score=0.833 total time=   4.1s
# [CV 4/5; 5/9] START dropout_rate=0.1, learn_rate=0.01...........................
# [CV 4/5; 5/9] END dropout_rate=0.1, learn_rate=0.01;, score=0.859 total time=   3.4s
# [CV 5/5; 5/9] START dropout_rate=0.1, learn_rate=0.01...........................
# [CV 5/5; 5/9] END dropout_rate=0.1, learn_rate=0.01;, score=0.821 total time=   3.5s
# [CV 1/5; 6/9] START dropout_rate=0.1, learn_rate=0.1............................
# [CV 1/5; 6/9] END dropout_rate=0.1, learn_rate=0.1;, score=0.747 total time=   3.5s
# [CV 2/5; 6/9] START dropout_rate=0.1, learn_rate=0.1............................
# [CV 2/5; 6/9] END dropout_rate=0.1, learn_rate=0.1;, score=0.608 total time=   6.3s
# [CV 3/5; 6/9] START dropout_rate=0.1, learn_rate=0.1............................
# [CV 3/5; 6/9] END dropout_rate=0.1, learn_rate=0.1;, score=0.795 total time=   3.5s
# [CV 4/5; 6/9] START dropout_rate=0.1, learn_rate=0.1............................
# [CV 4/5; 6/9] END dropout_rate=0.1, learn_rate=0.1;, score=0.744 total time=   4.8s
# [CV 5/5; 6/9] START dropout_rate=0.1, learn_rate=0.1............................
# [CV 5/5; 6/9] END dropout_rate=0.1, learn_rate=0.1;, score=0.782 total time=   3.5s
# [CV 1/5; 7/9] START dropout_rate=0.2, learn_rate=0.001..........................
# [CV 1/5; 7/9] END dropout_rate=0.2, learn_rate=0.001;, score=0.772 total time=   3.3s
# [CV 2/5; 7/9] START dropout_rate=0.2, learn_rate=0.001..........................
# [CV 2/5; 7/9] END dropout_rate=0.2, learn_rate=0.001;, score=0.595 total time=   6.0s
# [CV 3/5; 7/9] START dropout_rate=0.2, learn_rate=0.001..........................
# [CV 3/5; 7/9] END dropout_rate=0.2, learn_rate=0.001;, score=0.795 total time=   3.5s
# [CV 4/5; 7/9] START dropout_rate=0.2, learn_rate=0.001..........................
# [CV 4/5; 7/9] END dropout_rate=0.2, learn_rate=0.001;, score=0.821 total time=   3.3s
# [CV 5/5; 7/9] START dropout_rate=0.2, learn_rate=0.001..........................
# [CV 5/5; 7/9] END dropout_rate=0.2, learn_rate=0.001;, score=0.846 total time=   4.2s
# [CV 1/5; 8/9] START dropout_rate=0.2, learn_rate=0.01...........................
# [CV 1/5; 8/9] END dropout_rate=0.2, learn_rate=0.01;, score=0.759 total time=   3.5s
# [CV 2/5; 8/9] START dropout_rate=0.2, learn_rate=0.01...........................
# [CV 2/5; 8/9] END dropout_rate=0.2, learn_rate=0.01;, score=0.633 total time=   3.3s
# [CV 3/5; 8/9] START dropout_rate=0.2, learn_rate=0.01...........................
# [CV 3/5; 8/9] END dropout_rate=0.2, learn_rate=0.01;, score=0.833 total time=   3.4s
# [CV 4/5; 8/9] START dropout_rate=0.2, learn_rate=0.01...........................
# [CV 4/5; 8/9] END dropout_rate=0.2, learn_rate=0.01;, score=0.859 total time=   3.9s
# [CV 5/5; 8/9] START dropout_rate=0.2, learn_rate=0.01...........................
# [CV 5/5; 8/9] END dropout_rate=0.2, learn_rate=0.01;, score=0.821 total time=   3.3s
# [CV 1/5; 9/9] START dropout_rate=0.2, learn_rate=0.1............................
# [CV 1/5; 9/9] END dropout_rate=0.2, learn_rate=0.1;, score=0.722 total time=   3.3s
# [CV 2/5; 9/9] START dropout_rate=0.2, learn_rate=0.1............................
# [CV 2/5; 9/9] END dropout_rate=0.2, learn_rate=0.1;, score=0.620 total time=   6.0s
# [CV 3/5; 9/9] START dropout_rate=0.2, learn_rate=0.1............................
# [CV 3/5; 9/9] END dropout_rate=0.2, learn_rate=0.1;, score=0.782 total time=   3.2s
# [CV 4/5; 9/9] START dropout_rate=0.2, learn_rate=0.1............................
# [CV 4/5; 9/9] END dropout_rate=0.2, learn_rate=0.1;, score=0.705 total time=   3.2s
# [CV 5/5; 9/9] START dropout_rate=0.2, learn_rate=0.1............................
# [CV 5/5; 9/9] END dropout_rate=0.2, learn_rate=0.1;, score=0.782 total time=   6.0s
# Best: 0.7835767507553101, using {'dropout_rate': 0.1, 'learn_rate': 0.01}
# 0.7785459280014038 0.0971714643498988, with: {'dropout_rate': 0.0, 'learn_rate': 0.001}
# 0.7631937742233277 0.07304384802963809, with: {'dropout_rate': 0.0, 'learn_rate': 0.01}
# 0.7555988192558288 0.08685306599832904, with: {'dropout_rate': 0.0, 'learn_rate': 0.1}
# 0.7632262349128723 0.09025075011768932, with: {'dropout_rate': 0.1, 'learn_rate': 0.001}
# 0.7835767507553101 0.08044298090045933, with: {'dropout_rate': 0.1, 'learn_rate': 0.01}
# 0.7349886417388916 0.06669988630155739, with: {'dropout_rate': 0.1, 'learn_rate': 0.1}
# 0.7657254219055176 0.08891567033112933, with: {'dropout_rate': 0.2, 'learn_rate': 0.001}
# 0.7810451030731201 0.08096022229267262, with: {'dropout_rate': 0.2, 'learn_rate': 0.01}
# 0.7222005724906921 0.0597485052035856, with: {'dropout_rate': 0.2, 'learn_rate': 0.1}

# %%
# Random Seed

seed = 6
np.random.seed(seed)

from keras.layers import Dropout

# Start Defining the model

def create_model(activ, init):
  #create model
  model = Sequential()
  model.add(Dense(8, input_dim = 8, kernel_initializer = init, activation = activ))
  model.add(Dropout(0.1))
  model.add(Dense(4, input_dim = 8, kernel_initializer = init, activation = activ))
  model.add(Dropout(0.1))
  model.add(Dense(1, activation = 'sigmoid'))

  #compile the model
  adam = Adam(lr = 0.01)
  model.compile(loss = 'binary_crossentropy', optimizer = adam, metrics = ['accuracy'])
  return model

# Create Model
model = KerasClassifier(build_fn = create_model, epochs = 50, batch_size = 10, verbose = 0)

# Define GridSearch Parameters
activ = ['tanh', 'relu', 'linear', 'softmax']
init = ['uniform', 'normal', 'zero']

# Make a dictionary of grid search parameters
param_grid = dict(activ=activ,init=init)

# Build and Fit GridSearchCV
grid = GridSearchCV(estimator = model, param_grid = param_grid, cv = KFold(), verbose = 10)
grid_result = grid.fit(X_stand, Y)

# Summarise Results
print("Best: {0}, using {1}".format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']

for mean,stddev, param in zip(means,stds,params):
  print('{0} {1}, with: {2}'.format(mean,stddev,param))
# Out:
# <ipython-input-28-84a7d4b56b98>:25: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasClassifier(build_fn = create_model, epochs = 50, batch_size = 10, verbose = 0)
# /usr/local/lib/python3.10/dist-packages/keras/optimizers/legacy/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 1/5; 1/12] START activ=tanh, init=uniform...................................
# [CV 1/5; 1/12] END ....activ=tanh, init=uniform;, score=0.772 total time=   4.0s
# [CV 2/5; 1/12] START activ=tanh, init=uniform...................................
# [CV 2/5; 1/12] END ....activ=tanh, init=uniform;, score=0.620 total time=   3.8s
# [CV 3/5; 1/12] START activ=tanh, init=uniform...................................
# [CV 3/5; 1/12] END ....activ=tanh, init=uniform;, score=0.808 total time=   3.7s
# [CV 4/5; 1/12] START activ=tanh, init=uniform...................................
# [CV 4/5; 1/12] END ....activ=tanh, init=uniform;, score=0.859 total time=   3.4s
# [CV 5/5; 1/12] START activ=tanh, init=uniform...................................
# [CV 5/5; 1/12] END ....activ=tanh, init=uniform;, score=0.859 total time=   3.4s
# [CV 1/5; 2/12] START activ=tanh, init=normal....................................
# [CV 1/5; 2/12] END .....activ=tanh, init=normal;, score=0.785 total time=   6.1s
# [CV 2/5; 2/12] START activ=tanh, init=normal....................................
# [CV 2/5; 2/12] END .....activ=tanh, init=normal;, score=0.595 total time=   3.5s
# [CV 3/5; 2/12] START activ=tanh, init=normal....................................
# [CV 3/5; 2/12] END .....activ=tanh, init=normal;, score=0.782 total time=   3.4s
# [CV 4/5; 2/12] START activ=tanh, init=normal....................................
# [CV 4/5; 2/12] END .....activ=tanh, init=normal;, score=0.846 total time=   6.3s
# [CV 5/5; 2/12] START activ=tanh, init=normal....................................
# [CV 5/5; 2/12] END .....activ=tanh, init=normal;, score=0.833 total time=   3.5s
# [CV 1/5; 3/12] START activ=tanh, init=zero......................................
# [CV 1/5; 3/12] END .......activ=tanh, init=zero;, score=0.646 total time=   3.5s
# [CV 2/5; 3/12] START activ=tanh, init=zero......................................
# [CV 2/5; 3/12] END .......activ=tanh, init=zero;, score=0.570 total time=   3.9s
# [CV 3/5; 3/12] START activ=tanh, init=zero......................................
# [CV 3/5; 3/12] END .......activ=tanh, init=zero;, score=0.705 total time=   3.4s
# [CV 4/5; 3/12] START activ=tanh, init=zero......................................
# [CV 4/5; 3/12] END .......activ=tanh, init=zero;, score=0.744 total time=   3.4s
# [CV 5/5; 3/12] START activ=tanh, init=zero......................................
# [CV 5/5; 3/12] END .......activ=tanh, init=zero;, score=0.679 total time=   6.0s
# [CV 1/5; 4/12] START activ=relu, init=uniform...................................
# [CV 1/5; 4/12] END ....activ=relu, init=uniform;, score=0.759 total time=   4.1s
# [CV 2/5; 4/12] START activ=relu, init=uniform...................................
# [CV 2/5; 4/12] END ....activ=relu, init=uniform;, score=0.671 total time=   3.4s
# [CV 3/5; 4/12] START activ=relu, init=uniform...................................
# [CV 3/5; 4/12] END ....activ=relu, init=uniform;, score=0.808 total time=   4.2s
# [CV 4/5; 4/12] START activ=relu, init=uniform...................................
# [CV 4/5; 4/12] END ....activ=relu, init=uniform;, score=0.833 total time=   3.4s
# [CV 5/5; 4/12] START activ=relu, init=uniform...................................
# [CV 5/5; 4/12] END ....activ=relu, init=uniform;, score=0.679 total time=   6.2s
# [CV 1/5; 5/12] START activ=relu, init=normal....................................
# [CV 1/5; 5/12] END .....activ=relu, init=normal;, score=0.747 total time=   3.8s
# [CV 2/5; 5/12] START activ=relu, init=normal....................................
# [CV 2/5; 5/12] END .....activ=relu, init=normal;, score=0.658 total time=   3.4s
# [CV 3/5; 5/12] START activ=relu, init=normal....................................
# [CV 3/5; 5/12] END .....activ=relu, init=normal;, score=0.795 total time=   3.5s
# [CV 4/5; 5/12] START activ=relu, init=normal....................................
# [CV 4/5; 5/12] END .....activ=relu, init=normal;, score=0.859 total time=   6.0s
# [CV 5/5; 5/12] START activ=relu, init=normal....................................
# [CV 5/5; 5/12] END .....activ=relu, init=normal;, score=0.846 total time=   3.5s
# [CV 1/5; 6/12] START activ=relu, init=zero......................................
# [CV 1/5; 6/12] END .......activ=relu, init=zero;, score=0.646 total time=   3.4s
# [CV 2/5; 6/12] START activ=relu, init=zero......................................
# [CV 2/5; 6/12] END .......activ=relu, init=zero;, score=0.570 total time=   4.0s
# [CV 3/5; 6/12] START activ=relu, init=zero......................................
# [CV 3/5; 6/12] END .......activ=relu, init=zero;, score=0.705 total time=   3.4s
# [CV 4/5; 6/12] START activ=relu, init=zero......................................
# [CV 4/5; 6/12] END .......activ=relu, init=zero;, score=0.744 total time=   3.5s
# [CV 5/5; 6/12] START activ=relu, init=zero......................................
# [CV 5/5; 6/12] END .......activ=relu, init=zero;, score=0.679 total time=   3.8s
# [CV 1/5; 7/12] START activ=linear, init=uniform.................................
# [CV 1/5; 7/12] END ..activ=linear, init=uniform;, score=0.835 total time=   3.5s
# [CV 2/5; 7/12] START activ=linear, init=uniform.................................
# [CV 2/5; 7/12] END ..activ=linear, init=uniform;, score=0.633 total time=   4.1s
# [CV 3/5; 7/12] START activ=linear, init=uniform.................................
# [CV 3/5; 7/12] END ..activ=linear, init=uniform;, score=0.821 total time=   3.6s
# [CV 4/5; 7/12] START activ=linear, init=uniform.................................
# [CV 4/5; 7/12] END ..activ=linear, init=uniform;, score=0.846 total time=   6.3s
# [CV 5/5; 7/12] START activ=linear, init=uniform.................................
# [CV 5/5; 7/12] END ..activ=linear, init=uniform;, score=0.808 total time=   3.3s
# [CV 1/5; 8/12] START activ=linear, init=normal..................................
# [CV 1/5; 8/12] END ...activ=linear, init=normal;, score=0.835 total time=   6.0s
# [CV 2/5; 8/12] START activ=linear, init=normal..................................
# [CV 2/5; 8/12] END ...activ=linear, init=normal;, score=0.620 total time=   3.4s
# [CV 3/5; 8/12] START activ=linear, init=normal..................................
# [CV 3/5; 8/12] END ...activ=linear, init=normal;, score=0.833 total time=   3.5s
# [CV 4/5; 8/12] START activ=linear, init=normal..................................
# [CV 4/5; 8/12] END ...activ=linear, init=normal;, score=0.833 total time=   6.0s
# [CV 5/5; 8/12] START activ=linear, init=normal..................................
# [CV 5/5; 8/12] END ...activ=linear, init=normal;, score=0.833 total time=   3.5s
# [CV 1/5; 9/12] START activ=linear, init=zero....................................
# [CV 1/5; 9/12] END .....activ=linear, init=zero;, score=0.646 total time=   3.4s
# [CV 2/5; 9/12] START activ=linear, init=zero....................................
# [CV 2/5; 9/12] END .....activ=linear, init=zero;, score=0.570 total time=   4.0s
# [CV 3/5; 9/12] START activ=linear, init=zero....................................
# [CV 3/5; 9/12] END .....activ=linear, init=zero;, score=0.705 total time=   3.4s
# [CV 4/5; 9/12] START activ=linear, init=zero....................................
# [CV 4/5; 9/12] END .....activ=linear, init=zero;, score=0.744 total time=   3.3s
# [CV 5/5; 9/12] START activ=linear, init=zero....................................
# [CV 5/5; 9/12] END .....activ=linear, init=zero;, score=0.679 total time=   3.5s
# [CV 1/5; 10/12] START activ=softmax, init=uniform...............................
# [CV 1/5; 10/12] END activ=softmax, init=uniform;, score=0.734 total time=   6.3s
# [CV 2/5; 10/12] START activ=softmax, init=uniform...............................
# [CV 2/5; 10/12] END activ=softmax, init=uniform;, score=0.646 total time=   3.4s
# [CV 3/5; 10/12] START activ=softmax, init=uniform...............................
# [CV 3/5; 10/12] END activ=softmax, init=uniform;, score=0.846 total time=   6.0s
# [CV 4/5; 10/12] START activ=softmax, init=uniform...............................
# [CV 4/5; 10/12] END activ=softmax, init=uniform;, score=0.821 total time=   4.3s
# [CV 5/5; 10/12] START activ=softmax, init=uniform...............................
# [CV 5/5; 10/12] END activ=softmax, init=uniform;, score=0.872 total time=   3.5s
# [CV 1/5; 11/12] START activ=softmax, init=normal................................
# [CV 1/5; 11/12] END .activ=softmax, init=normal;, score=0.759 total time=   6.3s
# [CV 2/5; 11/12] START activ=softmax, init=normal................................
# [CV 2/5; 11/12] END .activ=softmax, init=normal;, score=0.633 total time=   3.5s
# [CV 3/5; 11/12] START activ=softmax, init=normal................................
# [CV 3/5; 11/12] END .activ=softmax, init=normal;, score=0.833 total time=   3.7s
# [CV 4/5; 11/12] START activ=softmax, init=normal................................
# [CV 4/5; 11/12] END .activ=softmax, init=normal;, score=0.846 total time=   6.4s
# [CV 5/5; 11/12] START activ=softmax, init=normal................................
# [CV 5/5; 11/12] END .activ=softmax, init=normal;, score=0.833 total time=   3.5s
# [CV 1/5; 12/12] START activ=softmax, init=zero..................................
# [CV 1/5; 12/12] END ...activ=softmax, init=zero;, score=0.734 total time=   4.0s
# [CV 2/5; 12/12] START activ=softmax, init=zero..................................
# [CV 2/5; 12/12] END ...activ=softmax, init=zero;, score=0.671 total time=   3.6s
# [CV 3/5; 12/12] START activ=softmax, init=zero..................................
# [CV 3/5; 12/12] END ...activ=softmax, init=zero;, score=0.808 total time=   3.4s
# [CV 4/5; 12/12] START activ=softmax, init=zero..................................
# [CV 4/5; 12/12] END ...activ=softmax, init=zero;, score=0.833 total time=   3.4s
# [CV 5/5; 12/12] START activ=softmax, init=zero..................................
# [CV 5/5; 12/12] END ...activ=softmax, init=zero;, score=0.872 total time=   4.1s
# Best: 0.7911392211914062, using {'activ': 'linear', 'init': 'normal'}
# 0.7836091995239258 0.08804121035835163, with: {'activ': 'tanh', 'init': 'uniform'}
# 0.7682570576667785 0.0903405234569121, with: {'activ': 'tanh', 'init': 'normal'}
# 0.6686789989471436 0.05899773033245815, with: {'activ': 'tanh', 'init': 'zero'}
# 0.7501785039901734 0.06571739507946062, with: {'activ': 'relu', 'init': 'uniform'}
# 0.7810126662254333 0.07315416822459617, with: {'activ': 'relu', 'init': 'normal'}
# 0.6686789989471436 0.05899773033245815, with: {'activ': 'relu', 'init': 'zero'}
# 0.7885426759719849 0.07890321637345102, with: {'activ': 'linear', 'init': 'uniform'}
# 0.7911392211914062 0.08544694452599808, with: {'activ': 'linear', 'init': 'normal'}
# 0.6686789989471436 0.05899773033245815, with: {'activ': 'linear', 'init': 'zero'}
# 0.7836416840553284 0.0831250445061881, with: {'activ': 'softmax', 'init': 'uniform'}
# 0.7810451030731201 0.08014402957073075, with: {'activ': 'softmax', 'init': 'normal'}
# 0.783576762676239 0.07208218691661544, with: {'activ': 'softmax', 'init': 'zero'}

# %%
# Random Seed

seed = 6
np.random.seed(seed)

from keras.layers import Dropout

# Start Defining the model

def create_model(neuron1, neuron2):
  #create model
  model = Sequential()
  model.add(Dense(neuron1, input_dim = 8, kernel_initializer = 'normal', activation = 'linear'))
  model.add(Dropout(0.1))
  model.add(Dense(neuron2, input_dim = neuron1, kernel_initializer = 'normal', activation = 'linear'))
  model.add(Dropout(0.1))
  model.add(Dense(1, activation = 'sigmoid'))

  #compile the model
  adam = Adam(lr = 0.01)
  model.compile(loss = 'binary_crossentropy', optimizer = adam, metrics = ['accuracy'])
  return model

# Create Model
model = KerasClassifier(build_fn = create_model, epochs = 50, batch_size = 10, verbose = 0)

# Define GridSearch Parameters
neuron1 = [4,8,16]
neuron2 = [2,4,8]

# Make a dictionary of grid search parameters
param_grid = dict(neuron1 = neuron1, neuron2 = neuron2)

# Build and Fit GridSearchCV
grid = GridSearchCV(estimator = model, param_grid = param_grid, cv = KFold(), refit = True, verbose = 10)
grid_result = grid.fit(X_stand, Y)

# Summarise Results
print("Best: {0}, using {1}".format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']

for mean,stddev, param in zip(means,stds,params):
  print('{0} {1}, with: {2}'.format(mean,stddev,param))
# Out:
# <ipython-input-29-cc2b1ae2154f>:25: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasClassifier(build_fn = create_model, epochs = 50, batch_size = 10, verbose = 0)
# /usr/local/lib/python3.10/dist-packages/keras/optimizers/legacy/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 1/5; 1/9] END .........neuron1=4, neuron2=2;, score=0.835 total time=   6.4s
# [CV 2/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 2/5; 1/9] END .........neuron1=4, neuron2=2;, score=0.633 total time=   3.2s
# [CV 3/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 3/5; 1/9] END .........neuron1=4, neuron2=2;, score=0.821 total time=   3.2s
# [CV 4/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 4/5; 1/9] END .........neuron1=4, neuron2=2;, score=0.821 total time=   4.9s
# [CV 5/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 5/5; 1/9] END .........neuron1=4, neuron2=2;, score=0.808 total time=   3.4s
# [CV 1/5; 2/9] START neuron1=4, neuron2=4........................................
# [CV 1/5; 2/9] END .........neuron1=4, neuron2=4;, score=0.835 total time=   3.5s
# [CV 2/5; 2/9] START neuron1=4, neuron2=4........................................
# [CV 2/5; 2/9] END .........neuron1=4, neuron2=4;, score=0.633 total time=   6.0s
# [CV 3/5; 2/9] START neuron1=4, neuron2=4........................................
# [CV 3/5; 2/9] END .........neuron1=4, neuron2=4;, score=0.821 total time=   3.5s
# [CV 4/5; 2/9] START neuron1=4, neuron2=4........................................
# [CV 4/5; 2/9] END .........neuron1=4, neuron2=4;, score=0.846 total time=   3.5s
# [CV 5/5; 2/9] START neuron1=4, neuron2=4........................................
# [CV 5/5; 2/9] END .........neuron1=4, neuron2=4;, score=0.833 total time=   6.0s
# [CV 1/5; 3/9] START neuron1=4, neuron2=8........................................
# [CV 1/5; 3/9] END .........neuron1=4, neuron2=8;, score=0.835 total time=   3.5s
# [CV 2/5; 3/9] START neuron1=4, neuron2=8........................................
# [CV 2/5; 3/9] END .........neuron1=4, neuron2=8;, score=0.620 total time=   3.4s
# [CV 3/5; 3/9] START neuron1=4, neuron2=8........................................
# [CV 3/5; 3/9] END .........neuron1=4, neuron2=8;, score=0.821 total time=   6.0s
# [CV 4/5; 3/9] START neuron1=4, neuron2=8........................................
# [CV 4/5; 3/9] END .........neuron1=4, neuron2=8;, score=0.846 total time=   3.4s
# [CV 5/5; 3/9] START neuron1=4, neuron2=8........................................
# [CV 5/5; 3/9] END .........neuron1=4, neuron2=8;, score=0.821 total time=   3.4s
# [CV 1/5; 4/9] START neuron1=8, neuron2=2........................................
# [CV 1/5; 4/9] END .........neuron1=8, neuron2=2;, score=0.835 total time=   4.0s
# [CV 2/5; 4/9] START neuron1=8, neuron2=2........................................
# [CV 2/5; 4/9] END .........neuron1=8, neuron2=2;, score=0.620 total time=   3.4s
# [CV 3/5; 4/9] START neuron1=8, neuron2=2........................................
# [CV 3/5; 4/9] END .........neuron1=8, neuron2=2;, score=0.821 total time=   3.2s
# [CV 4/5; 4/9] START neuron1=8, neuron2=2........................................
# [CV 4/5; 4/9] END .........neuron1=8, neuron2=2;, score=0.833 total time=   6.0s
# [CV 5/5; 4/9] START neuron1=8, neuron2=2........................................
# [CV 5/5; 4/9] END .........neuron1=8, neuron2=2;, score=0.808 total time=   3.4s
# [CV 1/5; 5/9] START neuron1=8, neuron2=4........................................
# [CV 1/5; 5/9] END .........neuron1=8, neuron2=4;, score=0.835 total time=   4.2s
# [CV 2/5; 5/9] START neuron1=8, neuron2=4........................................
# [CV 2/5; 5/9] END .........neuron1=8, neuron2=4;, score=0.620 total time=   6.1s
# [CV 3/5; 5/9] START neuron1=8, neuron2=4........................................
# [CV 3/5; 5/9] END .........neuron1=8, neuron2=4;, score=0.833 total time=   3.5s
# [CV 4/5; 5/9] START neuron1=8, neuron2=4........................................
# [CV 4/5; 5/9] END .........neuron1=8, neuron2=4;, score=0.846 total time=   3.4s
# [CV 5/5; 5/9] START neuron1=8, neuron2=4........................................
# [CV 5/5; 5/9] END .........neuron1=8, neuron2=4;, score=0.833 total time=   4.1s
# [CV 1/5; 6/9] START neuron1=8, neuron2=8........................................
# [CV 1/5; 6/9] END .........neuron1=8, neuron2=8;, score=0.835 total time=   3.4s
# [CV 2/5; 6/9] START neuron1=8, neuron2=8........................................
# [CV 2/5; 6/9] END .........neuron1=8, neuron2=8;, score=0.633 total time=   3.4s
# [CV 3/5; 6/9] START neuron1=8, neuron2=8........................................
# [CV 3/5; 6/9] END .........neuron1=8, neuron2=8;, score=0.821 total time=   6.0s
# [CV 4/5; 6/9] START neuron1=8, neuron2=8........................................
# [CV 4/5; 6/9] END .........neuron1=8, neuron2=8;, score=0.859 total time=   3.4s
# [CV 5/5; 6/9] START neuron1=8, neuron2=8........................................
# [CV 5/5; 6/9] END .........neuron1=8, neuron2=8;, score=0.821 total time=   3.4s
# [CV 1/5; 7/9] START neuron1=16, neuron2=2.......................................
# [CV 1/5; 7/9] END ........neuron1=16, neuron2=2;, score=0.835 total time=   6.0s
# [CV 2/5; 7/9] START neuron1=16, neuron2=2.......................................
# [CV 2/5; 7/9] END ........neuron1=16, neuron2=2;, score=0.633 total time=   3.4s
# [CV 3/5; 7/9] START neuron1=16, neuron2=2.......................................
# [CV 3/5; 7/9] END ........neuron1=16, neuron2=2;, score=0.833 total time=   3.3s
# [CV 4/5; 7/9] START neuron1=16, neuron2=2.......................................
# [CV 4/5; 7/9] END ........neuron1=16, neuron2=2;, score=0.846 total time=   6.0s
# [CV 5/5; 7/9] START neuron1=16, neuron2=2.......................................
# [CV 5/5; 7/9] END ........neuron1=16, neuron2=2;, score=0.808 total time=   3.4s
# [CV 1/5; 8/9] START neuron1=16, neuron2=4.......................................
# [CV 1/5; 8/9] END ........neuron1=16, neuron2=4;, score=0.823 total time=   3.4s
# [CV 2/5; 8/9] START neuron1=16, neuron2=4.......................................
# [CV 2/5; 8/9] END ........neuron1=16, neuron2=4;, score=0.633 total time=   6.8s
# [CV 3/5; 8/9] START neuron1=16, neuron2=4.......................................
# [CV 3/5; 8/9] END ........neuron1=16, neuron2=4;, score=0.833 total time=   6.5s
# [CV 4/5; 8/9] START neuron1=16, neuron2=4.......................................
# [CV 4/5; 8/9] END ........neuron1=16, neuron2=4;, score=0.833 total time=   6.3s
# [CV 5/5; 8/9] START neuron1=16, neuron2=4.......................................
# [CV 5/5; 8/9] END ........neuron1=16, neuron2=4;, score=0.808 total time=   3.4s
# [CV 1/5; 9/9] START neuron1=16, neuron2=8.......................................
# [CV 1/5; 9/9] END ........neuron1=16, neuron2=8;, score=0.835 total time=   6.0s
# [CV 2/5; 9/9] START neuron1=16, neuron2=8.......................................
# [CV 2/5; 9/9] END ........neuron1=16, neuron2=8;, score=0.608 total time=   3.5s
# [CV 3/5; 9/9] START neuron1=16, neuron2=8.......................................
# [CV 3/5; 9/9] END ........neuron1=16, neuron2=8;, score=0.821 total time=   3.4s
# [CV 4/5; 9/9] START neuron1=16, neuron2=8.......................................
# [CV 4/5; 9/9] END ........neuron1=16, neuron2=8;, score=0.846 total time=   4.3s
# [CV 5/5; 9/9] START neuron1=16, neuron2=8.......................................
# [CV 5/5; 9/9] END ........neuron1=16, neuron2=8;, score=0.833 total time=   3.5s
# Best: 0.7937033295631408, using {'neuron1': 8, 'neuron2': 4}
# 0.7834144711494446 0.0757629700930144, with: {'neuron1': 4, 'neuron2': 2}
# 0.7936708807945252 0.08079181748331918, with: {'neuron1': 4, 'neuron2': 4}
# 0.7885751366615296 0.08471627072558463, with: {'neuron1': 4, 'neuron2': 8}
# 0.7834469199180603 0.08220240183263726, with: {'neuron1': 8, 'neuron2': 2}
# 0.7937033295631408 0.08685539353586814, with: {'neuron1': 8, 'neuron2': 4}
# 0.7936708807945252 0.08160153117498936, with: {'neuron1': 8, 'neuron2': 8}
# 0.7911067724227905 0.08009971934827462, with: {'neuron1': 16, 'neuron2': 2}
# 0.786011016368866 0.07712416534514266, with: {'neuron1': 16, 'neuron2': 4}
# 0.7886075854301453 0.09087249991485369, with: {'neuron1': 16, 'neuron2': 8}

# %%
# generate predictions with optimal hyperparameters
y_pred = grid.predict(X_stand)
print(y_pred.shape)
print(y_pred[:5])
print(Y[:5])
# Out:
# 13/13 [==============================] - 0s 1ms/step
# (392, 1)
# [[0]
#  [1]
#  [0]
#  [1]
#  [1]]
# [0 1 1 1 1]

# %%
# Generate Classification Report
from sklearn.metrics import classification_report, accuracy_score

print(classification_report(Y,y_pred))
print(accuracy_score(Y,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.87      0.85       262
#            1       0.71      0.62      0.66       130
#
#     accuracy                           0.79       392
#    macro avg       0.76      0.74      0.75       392
# weighted avg       0.78      0.79      0.78       392
#
# 0.7882653061224489

# %%
# Example Datapoint

example = df.iloc[7]
prediction = grid.predict(X_stand[7].reshape(1,-1))

print(example)
print(prediction)
# Out:
# 1/1 [==============================] - 0s 34ms/step
# Pregnancies                   1.000
# Glucose                     103.000
# BloodPressure                30.000
# SkinThickness                38.000
# Insulin                      83.000
# BMI                          43.300
# DiabetesPedigreeFunction      0.183
# Age                          33.000
# Outcome                       0.000
# Name: 18, dtype: float64
# [[0]]
